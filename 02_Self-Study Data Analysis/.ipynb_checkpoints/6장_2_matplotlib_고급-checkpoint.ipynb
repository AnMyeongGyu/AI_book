# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.dpi'] = 100
plt.rc('font', family='D2coding')

# %%
import pandas as pd

ns_book7 = pd.read_csv('ns_book7.csv', low_memory=False)
ns_book7.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19

# %%
# value_counts() 출판사 개수를 세고 내림차순 정렬
top30_pubs = ns_book7['출판사'].value_counts()
top30_pubs
# Out:
# 문학동네        4410
# 민음사         3349
# 김영사         3246
# 웅진씽크빅       3227
# 시공사         2685
#             ...
# 해인서원           1
# 크릭앤리버코리아       1
# 한국장애인재단        1
# 돌아온 산          1
# 건강다이제스트        1
# Name: 출판사, Length: 21875, dtype: int64

# %%
top30_pubs = ns_book7['출판사'].value_counts()[:30]
top30_pubs_idx = ns_book7['출판사'].isin(top30_pubs.index)
top30_pubs_idx
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4          True
#           ...
# 376765    False
# 376766    False
# 376767     True
# 376768    False
# 376769    False
# Name: 출판사, Length: 376770, dtype: bool

# %%
# 상위 30개 출판사의 행만 가져옴 / 특정 열만 슬라이싱
ns_book9 = ns_book7[top30_pubs_idx][['출판사', '발행년도', '대출건수']]
ns_book9
# Out:
#            출판사  발행년도  대출건수
# 0          민음사  2021     0
# 4          김영사  2021     0
# 23        문학동네  2021     0
# 24         한길사  2021     0
# 39         현암사  2021     0
# ...        ...   ...   ...
# 376738  문학과지성사  1983     0
# 376739  문학과지성사  1983     0
# 376755     시공사  1995     0
# 376762     집문당  1990     0
# 376767   한국문화사  1996     0
#
# [51886 rows x 3 columns]

# %%
# 출판사별 발행년도에 대한 대출건수의 합을 구함
ns_book9 = ns_book9.groupby(by=['출판사', '발행년도']).sum()
ns_book9
# Out:
#            대출건수
# 출판사  발행년도
# 博英社  1947     0
#      1975     0
#      1977     0
#      1986     1
#      1987     1
# ...         ...
# 황금가지 2018   200
#      2019   133
#      2020    98
#      2021     1
#      2030     2
#
# [886 rows x 1 columns]

# %%
# reset index로 열 맞춰주고 황금가지 출판사만 뽑기
ns_book9 = ns_book9.reset_index()
ns_book9[ns_book9['출판사'] == '황금가지']
# Out:
#       출판사  발행년도  대출건수
# 858  황금가지  1995     0
# 859  황금가지  1996    67
# 860  황금가지  1997   116
# 861  황금가지  1998   526
# 862  황금가지  1999   505
# 863  황금가지  2000  1152
# 864  황금가지  2001   722
# 865  황금가지  2002  1493
# 866  황금가지  2003  2001
# 867  황금가지  2004  2744
# 868  황금가지  2005  2593
# 869  황금가지  2006  3541
# 870  황금가지  2007  3787
# 871  황금가지  2008  2391
# 872  황금가지  2009  2270
# 873  황금가지  2010   489
# 874  황금가지  2011   991
# 875  황금가지  2012  1169
# 876  황금가지  2013  1147
# 877  황금가지  2014   455
# 878  황금가지  2015   594
# 879  황금가지  2016   481
# 880  황금가지  2017   499
# 881  황금가지  2018   200
# 882  황금가지  2019   133
# 883  황금가지  2020    98
# 884  황금가지  2021     1
# 885  황금가지  2030     2

# %%
# line1 = 황금가지 연도별 대출건수 / line2 = 비룡소 연도별 대출건수
line1 = ns_book9[ns_book9['출판사'] == '황금가지']
line2 = ns_book9[ns_book9['출판사'] == '비룡소']
line2
# Out:
#      출판사  발행년도  대출건수
# 296  비룡소  1990     0
# 297  비룡소  1991     2
# 298  비룡소  1994   217
# 299  비룡소  1995    17
# 300  비룡소  1996    15
# 301  비룡소  1997    13
# 302  비룡소  1998   107
# 303  비룡소  1999    82
# 304  비룡소  2000   166
# 305  비룡소  2001   826
# 306  비룡소  2002   412
# 307  비룡소  2003  1286
# 308  비룡소  2004  2026
# 309  비룡소  2005  2574
# 310  비룡소  2006  1591
# 311  비룡소  2007  2164
# 312  비룡소  2008  2023
# 313  비룡소  2009  1719
# 314  비룡소  2010  1163
# 315  비룡소  2011   953
# 316  비룡소  2012   835
# 317  비룡소  2013   309
# 318  비룡소  2014   439
# 319  비룡소  2015   244
# 320  비룡소  2016   335
# 321  비룡소  2017   701
# 322  비룡소  2018   432
# 323  비룡소  2019   249
# 324  비룡소  2020   102
# 325  비룡소  2021     1

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(line1['발행년도'], line1['대출건수'])
ax.plot(line2['발행년도'], line2['대출건수'])
ax.set_title('년도별 대출건수')
fig.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9248\1164434814.py:5: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(line1['발행년도'], line1['대출건수'], label='황금가지')
ax.plot(line2['발행년도'], line2['대출건수'], label='비룡소')
ax.set_title('년도별 대출건수')
ax.legend()
fig.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9248\1746861815.py:6: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
for pub in top30_pubs.index[:5]:
    print(pub)
# Out:
# 문학동네
# 민음사
# 김영사
# 웅진씽크빅
# 시공사

# %%
#  상위 5새 출판사를 각각 반복
fig, ax = plt.subplots(figsize=(8, 6))
for pub in top30_pubs.index[:5]:
    # line에 각 출판사만 슬라이싱
    line = ns_book9[ns_book9['출판사'] == pub]
    ax.plot(line['발행년도'], line['대출건수'], label=pub)
ax.set_title('년도별 대출건수')
ax.legend()
ax.set_xlim(1985, 2025)
fig.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9248\3034620046.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
ns_book10 = ns_book9.pivot_table(index='출판사', columns='발행년도')
ns_book10.head()
# Out:
#      대출건수                                               ...                  \
# 발행년도 1947 1974 1975 1976 1977 1978 1979 1980 1981 1982  ...    2013    2014
# 출판사                                                     ...
# 博英社   0.0  NaN  0.0  NaN  0.0  NaN  NaN  NaN  NaN  NaN  ...     NaN   118.0
# 길벗    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  1162.0  1619.0
# 김영사   NaN  NaN  NaN  NaN  NaN  NaN  NaN  0.0  0.0  0.0  ...  1905.0  1881.0
# 넥서스   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  1828.0  1429.0
# 다산북스  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  1100.0  1361.0
#
#
# 발행년도    2015    2016    2017    2018   2019   2020  2021 2030
# 출판사
# 博英社     57.0    47.0     2.0     8.0    NaN    1.0   NaN  NaN
# 길벗    1410.0  1597.0  1626.0  1004.0  773.0  292.0  12.0  NaN
# 김영사   2726.0  2647.0  1094.0  1602.0  533.0  332.0  30.0  NaN
# 넥서스    765.0  1146.0   932.0   565.0   90.0   15.0   0.0  NaN
# 다산북스  1321.0  1137.0  1249.0   773.0  530.0  127.0  13.0  NaN
#
# [5 rows x 50 columns]

# %%
# value를 정해주지 않아서 ('대출건수', '년도') 형식으로 반환됨
ns_book10.columns[:10]
# Out:
# MultiIndex([('대출건수', 1947),
#             ('대출건수', 1974),
#             ('대출건수', 1975),
#             ('대출건수', 1976),
#             ('대출건수', 1977),
#             ('대출건수', 1978),
#             ('대출건수', 1979),
#             ('대출건수', 1980),
#             ('대출건수', 1981),
#             ('대출건수', 1982)],
#            names=[None, '발행년도'])

# %%
top10_pubs = top30_pubs.index[:10]
print(top10_pubs)
# Out:
# Index(['문학동네', '민음사', '김영사', '웅진씽크빅', '시공사', '창비', '문학과지성사', '위즈덤하우스', '학지사',
#        '한울'],
#       dtype='object')

# %%
year_cols = ns_book10.columns.get_level_values(1)
print(year_cols)
# Out:
# Int64Index([1947, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983,
#             1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994,
#             1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005,
#             2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016,
#             2017, 2018, 2019, 2020, 2021, 2030],
#            dtype='int64', name='발행년도')

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.stackplot(year_cols, ns_book10.loc[top10_pubs].fillna(0), labels=top10_pubs)
ax.set_title('년도별 대출건수')
ax.legend(loc='upper left')
ax.set_xlim(1985, 2025)
fig.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9248\1639555673.py:6: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# 막대 그래프는 겹쳐져서 생성
fig, ax = plt.subplots(figsize=(8, 6))
ax.bar(line1['발행년도'], line1['대출건수'], label='황금가지')
ax.bar(line2['발행년도'], line2['대출건수'], label='비룡소')
ax.set_title('년도별 대출건수')
ax.legend()
fig.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9248\536795627.py:6: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# 넓이를 조정하고 위치를 조정해서 비교 가능
fig, ax = plt.subplots(figsize=(8, 6))
ax.bar(line1['발행년도']-0.2, line1['대출건수'], width=0.4, label='황금가지')
ax.bar(line2['발행년도']+0.2, line2['대출건수'], width=0.4, label='비룡소')
ax.set_title('년도별 대출건수')
ax.legend()
fig.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9248\654794341.py:6: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# 막대그래프 예시
height1 = [5, 4, 7, 9, 8]
height2 = [3, 2, 4, 1, 2]

plt.bar(range(5), height1, width=0.5)
plt.bar(range(5), height2, bottom=height1, width=0.5)
plt.show()

# %%
# bottom을 설정하지 않고 두 값을 더해서 표기
height3 = [a + b for a, b in zip(height1, height2)]

plt.bar(range(5), height3, width=0.5)
plt.bar(range(5), height1, width=0.5)
plt.show()

# %%
# 상위 5개 출판사의 2013~2020 대출건수 슬라이싱
# [ 상위 5개 출판사 행 , (대출건수,년도)] 튜플 형식으로 범위 지정
ns_book10.loc[top10_pubs[:5], ('대출건수',2013):('대출건수',2020)]
# Out:
#          대출건수
# 발행년도     2013    2014    2015    2016    2017    2018    2019   2020
# 문학동네   6919.0  4904.0  4201.0  5301.0  4529.0  2306.0  1340.0  645.0
# 민음사    2219.0  4805.0  1907.0  1571.0  2782.0  1559.0   998.0  552.0
# 김영사    1905.0  1881.0  2726.0  2647.0  1094.0  1602.0   533.0  332.0
# 웅진씽크빅  3293.0  2072.0  1529.0  1029.0  1032.0   762.0   159.0   26.0
# 시공사    2433.0  1512.0  1745.0  1787.0  1287.0   566.0   322.0  221.0

# %%
# cumsum() 함수로 누적합으로 만들어줌
ns_book10.loc[top10_pubs[:5], ('대출건수',2013):('대출건수',2020)].cumsum()
# Out:
#           대출건수
# 발행년도      2013     2014     2015     2016     2017    2018    2019    2020
# 문학동네    6919.0   4904.0   4201.0   5301.0   4529.0  2306.0  1340.0   645.0
# 민음사     9138.0   9709.0   6108.0   6872.0   7311.0  3865.0  2338.0  1197.0
# 김영사    11043.0  11590.0   8834.0   9519.0   8405.0  5467.0  2871.0  1529.0
# 웅진씽크빅  14336.0  13662.0  10363.0  10548.0   9437.0  6229.0  3030.0  1555.0
# 시공사    16769.0  15174.0  12108.0  12335.0  10724.0  6795.0  3352.0  1776.0

# %%
# 상위 10개의 출판사 누적합 슬라이싱
ns_book12 = ns_book10.loc[top10_pubs].cumsum()
ns_book12
# Out:
#        대출건수                                                ...           \
# 발행년도   1947 1974 1975 1976 1977 1978 1979 1980  1981 1982  ...     2013
# 문학동네    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  ...   6919.0
# 민음사     NaN  1.0  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  ...   9138.0
# 김영사     NaN  NaN  NaN  NaN  NaN  NaN  NaN  0.0   0.0  0.0  ...  11043.0
# 웅진씽크빅   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  ...  14336.0
# 시공사     NaN  NaN  NaN  NaN  NaN  NaN  0.0  NaN   NaN  NaN  ...  16769.0
# 창비      NaN  NaN  NaN  0.0  0.0  2.0  NaN  NaN   NaN  1.0  ...  18356.0
# 문학과지성사  NaN  NaN  NaN  NaN  1.0  NaN  7.0  NaN  20.0  NaN  ...  19641.0
# 위즈덤하우스  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  ...  21702.0
# 학지사     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  ...  22574.0
# 한울      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  ...  23220.0
#
#
# 발행년도       2014     2015     2016     2017    2018    2019    2020   2021 2030
# 문학동네     4904.0   4201.0   5301.0   4529.0  2306.0  1340.0   645.0   18.0  NaN
# 민음사      9709.0   6108.0   6872.0   7311.0  3865.0  2338.0  1197.0   25.0  NaN
# 김영사     11590.0   8834.0   9519.0   8405.0  5467.0  2871.0  1529.0   55.0  NaN
# 웅진씽크빅   13662.0  10363.0  10548.0   9437.0  6229.0  3030.0  1555.0    NaN  NaN
# 시공사     15174.0  12108.0  12335.0  10724.0  6795.0  3352.0  1776.0   60.0  NaN
# 창비      17046.0  13519.0  14515.0  12459.0  7947.0  4120.0  2313.0   72.0  NaN
# 문학과지성사  18092.0  14393.0  15670.0  13046.0  8418.0  4450.0  2464.0   77.0  NaN
# 위즈덤하우스  20617.0  16777.0  17631.0  14542.0  9312.0  5123.0  2829.0  100.0  NaN
# 학지사     21550.0  17303.0  18271.0  15015.0  9463.0  5182.0  2844.0    NaN  NaN
# 한울      21622.0  17411.0  18276.0  15030.0  9484.0     NaN     NaN    NaN  NaN
#
# [10 rows x 50 columns]

# %%
fig, ax = plt.subplots(figsize=(8, 6))
for i in reversed(range(len(ns_book12))):
    bar = ns_book12.iloc[i]     # 행 추출
    label = ns_book12.index[i]  # 출판사 이름 추출
    ax.bar(year_cols, bar, label=label)
ax.set_title('년도별 대출건수')
ax.legend(loc='upper left')
ax.set_xlim(1985, 2025)
fig.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9248\478610987.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
data = top30_pubs[:10]
labels = top30_pubs.index[:10]

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.pie(data, labels=labels)
ax.set_title('출판사 도서비율')
fig.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9248\434946793.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
plt.pie([10,9], labels=['A제품', 'B제품'], startangle=90)
plt.title('제품의 매출비율')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.pie(data, labels=labels, startangle=90,
       # 숫자 표기 : autopct , 강조효과 : explode
       autopct='%.1f%%', explode=[0.1]+[0]*9)
ax.set_title('출판사 도서비율')
fig.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9248\4009653577.py:5: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(20, 16))

# 산점도
ns_book8 = ns_book7[top30_pubs_idx].sample(1000, random_state=42)
sc = axes[0, 0].scatter(ns_book8['발행년도'], ns_book8['출판사'], 
                        linewidths=0.5, edgecolors='k', alpha=0.3,
                        s=ns_book8['대출건수'], c=ns_book8['대출건수'], cmap='jet')
axes[0, 0].set_title('출판사별 발행도서')
fig.colorbar(sc, ax=axes[0, 0])

# 스택 선 그래프
axes[0, 1].stackplot(year_cols, ns_book10.loc[top10_pubs].fillna(0), 
                     labels=top10_pubs)
axes[0, 1].set_title('년도별 대출건수')
axes[0, 1].legend(loc='upper left')
axes[0, 1].set_xlim(1985, 2025)

# 스택 막대 그래프
for i in reversed(range(len(ns_book12))):
    bar = ns_book12.iloc[i]     # 행 추출
    label = ns_book12.index[i]  # 출판사 이름 추출
    axes[1, 0].bar(year_cols, bar, label=label)
axes[1, 0].set_title('년도별 대출건수')
axes[1, 0].legend(loc='upper left')
axes[1, 0].set_xlim(1985, 2025)

# 원 그래프
axes[1, 1].pie(data, labels=labels, startangle=90,
               autopct='%.1f%%', explode=[0.1]+[0]*9)
axes[1, 1].set_title('출판사 도서비율')

fig.savefig('all_in_one.png')
fig.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9248\1281370616.py:33: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# pivot table에 value를 구성
ns_book11 = ns_book9.pivot_table(index='발행년도', columns='출판사', values='대출건수')
ns_book11.loc[2000:2005]
# Out:
# 출판사     博英社      길벗     김영사     넥서스   다산북스  랜덤하우스코리아  문학과지성사    문학동네     민음사  \
# 발행년도
# 2000  237.0     7.0   854.0   194.0    NaN       3.0   316.0   806.0   836.0
# 2001  267.0   202.0  2269.0   228.0    NaN      17.0   449.0  1373.0  1363.0
# 2002  458.0   472.0  2525.0  1154.0    NaN      20.0   686.0  1442.0  1388.0
# 2003  444.0   795.0  3130.0  3069.0    NaN     489.0  1262.0  2750.0  1453.0
# 2004  630.0   976.0  4804.0  2355.0  212.0     618.0   952.0  3012.0  1864.0
# 2005  788.0  2162.0  7684.0  1162.0  509.0     941.0  1827.0  3952.0  2546.0
#
# 출판사   북이십일 21세기북스  ...      창비     책세상  커뮤니케이션북스     학지사  한국문화사  한국학술정보  \
# 발행년도               ...
# 2000          NaN  ...    57.0   369.0      37.0   988.0   84.0    36.0
# 2001          NaN  ...    70.0   355.0     184.0   582.0  110.0     3.0
# 2002          NaN  ...     0.0   794.0      80.0   625.0  134.0    47.0
# 2003          NaN  ...   191.0   289.0     110.0  1006.0  215.0    95.0
# 2004         42.0  ...  2268.0   637.0     476.0  1270.0  392.0    91.0
# 2005          NaN  ...  2256.0  1103.0     820.0  1179.0  243.0   123.0
#
# 출판사      한길사     한울    현암사    황금가지
# 발행년도
# 2000   536.0  287.0  274.0  1152.0
# 2001  1626.0  305.0  481.0   722.0
# 2002   777.0  450.0  398.0  1493.0
# 2003  1114.0  636.0  471.0  2001.0
# 2004  1318.0  502.0  661.0  2744.0
# 2005  1461.0  767.0  835.0  2593.0
#
# [6 rows x 30 columns]

# %%
import numpy as np
# pivot table을 생성하는 경우 aggfunc으로 집계방식을 정해야함, 기본값은 평균
ns_book11 = ns_book7[top30_pubs_idx].pivot_table(
    index='발행년도', columns='출판사', 
    values='대출건수', aggfunc=np.sum)
ns_book11.loc[2000:2005]
# Out:
# 출판사     博英社      길벗     김영사     넥서스   다산북스  랜덤하우스코리아  문학과지성사    문학동네     민음사  \
# 발행년도
# 2000  237.0     7.0   854.0   194.0    NaN       3.0   316.0   806.0   836.0
# 2001  267.0   202.0  2269.0   228.0    NaN      17.0   449.0  1373.0  1363.0
# 2002  458.0   472.0  2525.0  1154.0    NaN      20.0   686.0  1442.0  1388.0
# 2003  444.0   795.0  3130.0  3069.0    NaN     489.0  1262.0  2750.0  1453.0
# 2004  630.0   976.0  4804.0  2355.0  212.0     618.0   952.0  3012.0  1864.0
# 2005  788.0  2162.0  7684.0  1162.0  509.0     941.0  1827.0  3952.0  2546.0
#
# 출판사   북이십일 21세기북스  ...      창비     책세상  커뮤니케이션북스     학지사  한국문화사  한국학술정보  \
# 발행년도               ...
# 2000          NaN  ...    57.0   369.0      37.0   988.0   84.0    36.0
# 2001          NaN  ...    70.0   355.0     184.0   582.0  110.0     3.0
# 2002          NaN  ...     0.0   794.0      80.0   625.0  134.0    47.0
# 2003          NaN  ...   191.0   289.0     110.0  1006.0  215.0    95.0
# 2004         42.0  ...  2268.0   637.0     476.0  1270.0  392.0    91.0
# 2005          NaN  ...  2256.0  1103.0     820.0  1179.0  243.0   123.0
#
# 출판사      한길사     한울    현암사    황금가지
# 발행년도
# 2000   536.0  287.0  274.0  1152.0
# 2001  1626.0  305.0  481.0   722.0
# 2002   777.0  450.0  398.0  1493.0
# 2003  1114.0  636.0  471.0  2001.0
# 2004  1318.0  502.0  661.0  2744.0
# 2005  1461.0  767.0  835.0  2593.0
#
# [6 rows x 30 columns]

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ns_book11[top10_pubs].plot.area(ax=ax, title='년도별 대출건수',
                                xlim=(1985, 2025))
ax.legend(loc='upper left')
fig.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9248\1633203849.py:5: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ns_book11.loc[1985:2025, top10_pubs].plot.bar(
    ax=ax, title='년도별 대출건수', stacked=True, width=0.8)
ax.legend(loc='upper left')
fig.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9248\261850259.py:5: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
